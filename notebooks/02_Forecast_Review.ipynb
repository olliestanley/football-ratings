# %%
from autoscout.util import load_csv

# %%
epl_df = load_csv("../data/preds/epl_2022.csv")

# %%
epl_df.head()
# Out:
#          date       home_team  home_xg  away_xg       away_team  home_goals  \
# 0  2021-08-13       Brentford      1.3      1.4         Arsenal           2
# 1  2021-08-14  Manchester Utd      1.5      0.6    Leeds United           5
# 2  2021-08-14         Watford      1.0      1.2     Aston Villa           3
# 3  2021-08-14         Chelsea      0.9      0.3  Crystal Palace           3
# 4  2021-08-14         Everton      2.4      0.7     Southampton           3
#
#    away_goals  home_att_rating  home_def_rating  away_att_rating  \
# 0           0           994.56           997.76          1002.24
# 1           1          1000.96          1023.36           976.64
# 2           2           984.96          1004.16           995.84
# 3           0           981.76          1032.96           967.04
# 4           1          1029.76          1020.16           979.84
#
#    away_def_rating  home_pred  away_pred  outcome  home_prob  draw_prob  \
# ...

# %%
epl_df.tail(20)
# Out:
#            date        home_team  home_xg  away_xg        away_team  \
# 360  2022-05-15         West Ham      1.3      2.5  Manchester City
# 361  2022-05-15     Leeds United      2.0      2.2         Brighton
# 362  2022-05-15           Wolves      0.9      1.3     Norwich City
# 363  2022-05-15      Aston Villa      1.0      1.3   Crystal Palace
# 364  2022-05-15          Everton      1.8      1.6        Brentford
# 365  2022-05-16    Newcastle Utd      2.1      0.6          Arsenal
# 366  2022-05-17      Southampton      0.1      1.5        Liverpool
# 367  2022-05-19          Everton      0.8      1.4   Crystal Palace
# 368  2022-05-19      Aston Villa      1.3      1.6          Burnley
# 369  2022-05-19          Chelsea      1.7      0.1   Leicester City
# 370  2022-05-22         Brighton      1.7      0.3         West Ham
# 371  2022-05-22        Brentford      1.2      1.4     Leeds United
# 372  2022-05-22   Leicester City      2.3      1.2      Southampton
# ...
